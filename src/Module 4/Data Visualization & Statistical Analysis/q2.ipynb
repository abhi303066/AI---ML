# %% [markdown]
# **Univariate Analysis (Single Feature Analysis)**<br>
#
# Objective: Understand the distribution and characteristics of a single feature using histograms boxplots, and violin plots.<br>
#
# Dataset: Use the Iris dataset or any dataset with multiple numerical features.

# %% [markdown]
# Title: Histogram<br>
#
# Task 1: Plot a histogram of the petal length feature.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset (replace with your own dataset if necessary)
from sklearn.datasets import load_iris
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Plot histogram of petal length
plt.figure(figsize=(8, 6))
sns.histplot(df['petal length (cm)'], bins=20, kde=True, color='skyblue')

# Add labels and title
plt.title('Histogram of Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# Title: Boxplots<br>
#
# Task 2: Plot a boxplot of the petal length feature.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset (replace with your own dataset if necessary)
from sklearn.datasets import load_iris
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Plot boxplot of petal length
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['petal length (cm)'], color='lightgreen')

# Add labels and title
plt.title('Boxplot of Petal Length')
plt.xlabel('Petal Length (cm)')

# Show the plot
plt.show()

# %% [markdown]
# Title: Violin Plots<br>
#
# Task 3: Plot a violin plot of the petal length feature.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset (replace with your own dataset if necessary)
from sklearn.datasets import load_iris
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Plot violin plot of petal length
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['petal length (cm)'], color='lightblue')

# Add labels and title
plt.title('Violin Plot of Petal Length')
plt.xlabel('Petal Length (cm)')

# Show the plot
plt.show()

# %% [markdown]
# **Bivariate Analysis (Relationships Between Features)**<br>
#
# Objective: Explore relationships between two features using scatter plots and correlation heatmaps.

# %% [markdown]
# Title: Scatter Plots<br>
#
# Task 1: Create a scatter plot between sepal length and sepal width.<br>
# Task 2: Scatter plot between petal length and petal width.<br>
# Task 3: Scatter plot between sepal length and petal length.<br>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Set the size of the plot
plt.figure(figsize=(15, 5))

# Task 1: Scatter plot between Sepal Length and Sepal Width
plt.subplot(1, 3, 1)
sns.scatterplot(x=df['sepal length (cm)'], y=df['sepal width (cm)'], color='blue')
plt.title('Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')

# Task 2: Scatter plot between Petal Length and Petal Width
plt.subplot(1, 3, 2)
sns.scatterplot(x=df['petal length (cm)'], y=df['petal width (cm)'], color='green')
plt.title('Petal Length vs. Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')

# Task 3: Scatter plot between Sepal Length and Petal Length
plt.subplot(1, 3, 3)
sns.scatterplot(x=df['sepal length (cm)'], y=df['petal length (cm)'], color='purple')
plt.title('Sepal Length vs. Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Title: Correlation Heatmaps<br>
#
# Task 1: Generate a correlation heatmap of the dataset.<br>
# Task 2: Highlight correlation between sepal length and petal length.<br>
# Task 3: Highlight correlation between petal width and petal length.<br>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Task 1: Generate a full correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar=True)
plt.title('Correlation Heatmap of the Dataset')
plt.show()

# Task 2: Highlight correlation between Sepal Length and Petal Length
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix[['sepal length (cm)', 'petal length (cm)']], annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar=True)
plt.title('Correlation between Sepal Length and Petal Length')
plt.show()

# Task 3: Highlight correlation between Petal Width and Petal Length
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix[['petal width (cm)', 'petal length (cm)']], annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, cbar=True)
plt.title('Correlation between Petal Width and Petal Length')
plt.show()

# %% [markdown]
# **Multivariate Analysis (Higher-Dimensional Data Relationships)**<br>
# Objective: Analyze relationships in higher-dimensional data using pair plots and PCA.

# %% [markdown]
# Title: Pair Plots<br>
#
# Task 1: Create a pair plot for the Iris dataset.<br>
# Task 2: Focus on a subset of features (e.g., only petal dimensions).<br>
# Task 3: Exclude one class to observe differences.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add the target labels (species) to the DataFrame
df['species'] = iris.target_names[iris.target]

# Task 1: Create a pair plot for the entire Iris dataset
sns.pairplot(df, hue='species', palette='Set1', markers=["o", "s", "D"])
plt.title('Pair Plot of the Iris Dataset')
plt.show()

# Task 2: Focus on a subset of features (e.g., only petal dimensions)
df_petal = df[['petal length (cm)', 'petal width (cm)', 'species']]
sns.pairplot(df_petal, hue='species', palette='Set1', markers=["o", "s", "D"])
plt.title('Pair Plot of Petal Dimensions')
plt.show()

# Task 3: Exclude one class to observe differences (e.g., Exclude Setosa)
df_no_setosa = df[df['species'] != 'setosa']
sns.pairplot(df_no_setosa, hue='species', palette='Set1', markers=["o", "s"])
plt.title('Pair Plot Excluding Setosa')
plt.show()

# %% [markdown]
# Title: Principal Component Analysis (PCA)<br>
#
# Task 1: Perform PCA and plot the first two principal components.<br>
# Task 2: Visualize explained variance by each component.<br>
# Task 3: Retain more components and visualize in 3D.

# %%
# Task 2: Visualize explained variance by each component
explained_variance = pca.explained_variance_ratio_

# Plot the explained variance
plt.figure(figsize=(8, 6))
sns.barplot(x=['PC1', 'PC2'], y=explained_variance, palette='coolwarm')
plt.title('Explained Variance by Each Principal Component')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()
# Out:
# /tmp/ipykernel_31059/3903377147.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['PC1', 'PC2'], y=explained_variance, palette='coolwarm')

# %% [markdown]
# **Statistical Analysis in EDA**<br>
#
# Objective: Calculate basic statistical metrics and explore the relationship between features using correlation and covariance.<br>

# %% [markdown]
# Title: Descriptive Statistics<br>
#
# Task 1: Calculate mean, median, and standard deviation of petal length.<br>
# Task 2: Calculate skewness and kurtosis of sepal width.<br>
# Task 3: Calculate mean, median, and standard deviation of sepal length.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from scipy.stats import skew, kurtosis

# Load the Iris dataset
iris = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Task 1: Calculate mean, median, and standard deviation of petal length
petal_length = df['petal length (cm)']
mean_petal_length = petal_length.mean()
median_petal_length = petal_length.median()
std_petal_length = petal_length.std()

print(f"Task 1: Petal Length Statistics")
print(f"Mean: {mean_petal_length:.2f}")
print(f"Median: {median_petal_length:.2f}")
print(f"Standard Deviation: {std_petal_length:.2f}")
print()

# Task 2: Calculate skewness and kurtosis of sepal width
sepal_width = df['sepal width (cm)']
skewness_sepal_width = skew(sepal_width)
kurtosis_sepal_width = kurtosis(sepal_width)

print(f"Task 2: Sepal Width Statistics")
print(f"Skewness: {skewness_sepal_width:.2f}")
print(f"Kurtosis: {kurtosis_sepal_width:.2f}")
print()

# Task 3: Calculate mean, median, and standard deviation of sepal length
sepal_length = df['sepal length (cm)']
mean_sepal_length = sepal_length.mean()
median_sepal_length = sepal_length.median()
std_sepal_length = sepal_length.std()

print(f"Task 3: Sepal Length Statistics")
print(f"Mean: {mean_sepal_length:.2f}")
print(f"Median: {median_sepal_length:.2f}")
print(f"Standard Deviation: {std_sepal_length:.2f}")
# Out:
# Task 1: Petal Length Statistics
# Mean: 3.76
# Median: 4.35
# Standard Deviation: 1.77
#
# Task 2: Sepal Width Statistics
# Skewness: 0.32
# Kurtosis: 0.18
#
# Task 3: Sepal Length Statistics
# Mean: 5.84
# Median: 5.80
# Standard Deviation: 0.83

# %% [markdown]
# Title: Correlation & Covariance<br>
#
# Task 1: Compute correlation between sepal length and petal length.<br>
# Task 2: Compute covariance between petal width and sepal width.<br>
# Task 3: Determine the most correlated pair of features.<br>

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Task 1: Compute correlation between sepal length and petal length
correlation = df['sepal length (cm)'].corr(df['petal length (cm)'])
print("Task 1: Correlation between sepal length and petal length:")
print(f"{correlation:.2f}\n")

# Task 2: Compute covariance between petal width and sepal width
covariance = df['petal width (cm)'].cov(df['sepal width (cm)'])
print("Task 2: Covariance between petal width and sepal width:")
print(f"{covariance:.2f}\n")

# Task 3: Determine the most correlated pair of features
correlation_matrix = df.corr()

# Unstack and sort correlation values
correlation_pairs = correlation_matrix.abs().unstack().sort_values(ascending=False)

# Exclude self-correlation (1.0) and find the most correlated pair
most_correlated = correlation_pairs[correlation_pairs < 1.0].idxmax()
highest_value = correlation_pairs[correlation_pairs < 1.0].max()

print("Task 3: Most correlated pair of features:")
print(f"{most_correlated} with correlation of {highest_value:.2f}")
